# %% [markdown]
# # Building The Heisman Dataset
# ***Sean Steinle***
#
#
# In this notebook, we'll be pulling together the data we need to answer our questions about the Heisman award.

# %%
#Import Libraries
import cfbd
import pandas

# %%
#API Configuration
configuration = cfbd.Configuration()
configuration.api_key['Authorization'] = 'Jr1LRSHRWqFsEIwxZcp0K/NBQRciKdGb9E+GPLFJHHKdFGkShUyyxdhDlZISY2NB'
configuration.api_key_prefix['Authorization'] = 'Bearer'

players_api = cfbd.PlayersApi(cfbd.ApiClient(configuration))
teams_api = cfbd.TeamsApi(cfbd.ApiClient(configuration))

# %%
df = players_api.get_player_season_stats(year=2020,team="Pittsburgh")

# %%
type(df)
# Out:
# list

# %%
df
# Out:
# [{'category': 'interceptions',
#   'conference': 'ACC',
#   'player': 'Erick Hallett',
#   'player_id': 4373320,
#   'season': None,
#   'stat': 2.0,
#   'stat_type': 'INT',
#   'team': 'Pittsburgh'},
#  {'category': 'receiving',
#   'conference': 'ACC',
#   'player': 'Shocky Jacques-Louis',
#   'player_id': 4361732,
#   'season': None,
#   'stat': 26.0,
#   'stat_type': 'REC',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Tre Tipton',
#   'player_id': 3895797,
#   'season': None,
#   'stat': 1.0,
#   'stat_type': 'TOT',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Cam Bright',
#   'player_id': 4240713,
#   'season': None,
#   'stat': 7.5,
#   'stat_type': 'TFL',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'John Petrishen',
#   'player_id': 3929651,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'PD',
#   'team': 'Pittsburgh'},
#  {'category': 'receiving',
#   'conference': 'ACC',
#   'player': 'Kyi Wright',
#   'player_id': 4428940,
#   'season': None,
#   'stat': 34.0,
#   'stat_type': 'YDS',
#   'team': 'Pittsburgh'},
#  {'category': 'rushing',
#   'conference': 'ACC',
#   'player': 'Brandon Hill',
#   'player_id': 4568662,
#   'season': None,
#   'stat': 3.0,
#   'stat_type': 'YPC',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Cal Adomitis',
#   'player_id': 4240719,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'TD',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Jordan Addison',
#   'player_id': 4429205,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'SACKS',
#   'team': 'Pittsburgh'},
#  {'category': 'puntReturns',
#   'conference': 'ACC',
#   'player': 'Todd Sibley Jr.',
#   'player_id': 4240711,
#   'season': None,
#   'stat': 1.0,
#   'stat_type': 'NO',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Phil Campbell',
#   'player_id': 4036052,
#   'season': None,
#   'stat': 4.5,
#   'stat_type': 'SACKS',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Marquis Williams',
#   'player_id': 4373315,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'TFL',
#   'team': 'Pittsburgh'},
#  {'category': 'fumbles',
#   'conference': 'ACC',
#   'player': 'Vincent Davis',
#   'player_id': 4568660,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'REC',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'John Petrishen',
#   'player_id': 3929651,
#   'season': None,
#   'stat': 10.0,
#   'stat_type': 'TOT',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Taysir Mack',
#   'player_id': 4045291,
#   'season': None,
#   'stat': 1.0,
#   'stat_type': 'TOT',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Todd Sibley Jr.',
#   'player_id': 4240711,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'PD',
#   'team': 'Pittsburgh'},
#  {'category': 'rushing',
#   'conference': 'ACC',
#   'player': 'Daniel Carter',
#   'player_id': 4568658,
#   'season': None,
#   'stat': 64.0,
#   'stat_type': 'YDS',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Shocky Jacques-Louis',
#   'player_id': 4361732,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'PD',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'A.J. Woods',
#   'player_id': 4428932,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'QB HUR',
#   'team': 'Pittsburgh'},
#  {'category': 'receiving',
#   'conference': 'ACC',
#   'player': 'A.J. Davis',
#   'player_id': 4240710,
#   'season': None,
#   'stat': 10.0,
#   'stat_type': 'REC',
#   'team': 'Pittsburgh'},
#  {'category': 'receiving',
#   'conference': 'ACC',
#   'player': 'DJ Turner',
#   'player_id': 4036211,
#   'season': None,
#   'stat': 44.0,
#   'stat_type': 'REC',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Bam Brima',
#   'player_id': 4426774,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'TFL',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Brandon George',
#   'player_id': 4568661,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'SACKS',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Devin Danielson',
#   'player_id': 4373336,
#   'season': None,
#   'stat': 7.0,
#   'stat_type': 'SOLO',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Tre Tipton',
#   'player_id': 3895797,
#   'season': None,
#   'stat': 1.0,
#   'stat_type': 'SOLO',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Marquis Williams',
#   'player_id': 4373315,
#   'season': None,
#   'stat': 17.0,
#   'stat_type': 'SOLO',
#   'team': 'Pittsburgh'},
#  {'category': 'fumbles',
#   'conference': 'ACC',
#   'player': 'Nick Patti',
#   'player_id': 4373314,
#   'season': None,
#   'stat': 1.0,
#   'stat_type': 'FUM',
#   'team': 'Pittsburgh'},
#  {'category': 'receiving',
#   'conference': 'ACC',
#   'player': 'Gavin Thomson',
#   'player_id': 4574964,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'TD',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Kenny Pickett',
#   'player_id': 4240703,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'TFL',
#   'team': 'Pittsburgh'},
#  {'category': 'passing',
#   'conference': 'ACC',
#   'player': 'Kenny Pickett',
#   'player_id': 4240703,
#   'season': None,
#   'stat': 7.2,
#   'stat_type': 'YPA',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': ' Team',
#   'player_id': -7111,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'TFL',
#   'team': 'Pittsburgh'},
#  {'category': 'receiving',
#   'conference': 'ACC',
#   'player': 'DJ Turner',
#   'player_id': 4036211,
#   'season': None,
#   'stat': 14.4,
#   'stat_type': 'YPR',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Rashad Battle',
#   'player_id': 4429256,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'QB HUR',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Tre Tipton',
#   'player_id': 3895797,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'SACKS',
#   'team': 'Pittsburgh'},
#  {'category': 'receiving',
#   'conference': 'ACC',
#   'player': 'Daniel Carter',
#   'player_id': 4568658,
#   'season': None,
#   'stat': 5.0,
#   'stat_type': 'YPR',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Nate Temple',
#   'player_id': 4428652,
#   'season': None,
#   'stat': 1.0,
#   'stat_type': 'QB HUR',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Kenny Pickett',
#   'player_id': 4240703,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'SACKS',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Buddy Mack III',
#   'player_id': 4689567,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'QB HUR',
#   'team': 'Pittsburgh'},
#  {'category': 'punting',
#   'conference': 'ACC',
#   'player': 'Kirk Christodoulou',
#   'player_id': 4240729,
#   'season': None,
#   'stat': 53.0,
#   'stat_type': 'NO',
#   'team': 'Pittsburgh'},
#  {'category': 'receiving',
#   'conference': 'ACC',
#   'player': 'Todd Sibley Jr.',
#   'player_id': 4240711,
#   'season': None,
#   'stat': 7.0,
#   'stat_type': 'YPR',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Wendell Davis',
#   'player_id': 4373324,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'SACKS',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Bangally Kamara',
#   'player_id': 4432325,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'PD',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Brandon George',
#   'player_id': 4568661,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'QB HUR',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Erick Hallett',
#   'player_id': 4373320,
#   'season': None,
#   'stat': 20.0,
#   'stat_type': 'SOLO',
#   'team': 'Pittsburgh'},
#  {'category': 'receiving',
#   'conference': 'ACC',
#   'player': 'Jordan Addison',
#   'player_id': 4429205,
#   'season': None,
#   'stat': 666.0,
#   'stat_type': 'YDS',
#   'team': 'Pittsburgh'},
#  {'category': 'rushing',
#   'conference': 'ACC',
#   'player': 'Israel Abanikanda',
#   'player_id': 4429202,
#   'season': None,
#   'stat': 1.0,
#   'stat_type': 'TD',
#   'team': 'Pittsburgh'},
#  {'category': 'puntReturns',
#   'conference': 'ACC',
#   'player': 'Jordan Addison',
#   'player_id': 4429205,
#   'season': None,
#   'stat': 7.5,
#   'stat_type': 'AVG',
#   'team': 'Pittsburgh'},
#  {'category': 'rushing',
#   'conference': 'ACC',
#   'player': 'Vincent Davis',
#   'player_id': 4568660,
#   'season': None,
#   'stat': 74.0,
#   'stat_type': 'LONG',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'A.J. Roberts',
#   'player_id': 4689572,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'SACKS',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Jared Campbell',
#   'player_id': 4574972,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'SACKS',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Devin Danielson',
#   'player_id': 4373336,
#   'season': None,
#   'stat': 3.0,
#   'stat_type': 'TFL',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Rashad Battle',
#   'player_id': 4429256,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'PD',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Rashad Weaver',
#   'player_id': 4036076,
#   'season': None,
#   'stat': 7.5,
#   'stat_type': 'SACKS',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Cam Bright',
#   'player_id': 4240713,
#   'season': None,
#   'stat': 1.0,
#   'stat_type': 'PD',
#   'team': 'Pittsburgh'},
#  {'category': 'rushing',
#   'conference': 'ACC',
#   'player': 'A.J. Davis',
#   'player_id': 4240710,
#   'season': None,
#   'stat': 61.0,
#   'stat_type': 'CAR',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Paris Ford',
#   'player_id': 4240705,
#   'season': None,
#   'stat': 1.0,
#   'stat_type': 'QB HUR',
#   'team': 'Pittsburgh'},
#  {'category': 'interceptions',
#   'conference': 'ACC',
#   'player': 'Jason Pinnock',
#   'player_id': 4240706,
#   'season': None,
#   'stat': 6.7,
#   'stat_type': 'AVG',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Keyshon Camp',
#   'player_id': 4036051,
#   'season': None,
#   'stat': 2.0,
#   'stat_type': 'QB HUR',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Habakkuk Baldonado',
#   'player_id': 4373335,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'TFL',
#   'team': 'Pittsburgh'},
#  {'category': 'rushing',
#   'conference': 'ACC',
#   'player': 'Davis Beville',
#   'player_id': 4428887,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'TD',
#   'team': 'Pittsburgh'},
#  {'category': 'receiving',
#   'conference': 'ACC',
#   'player': 'Jordan Addison',
#   'player_id': 4429205,
#   'season': None,
#   'stat': 4.0,
#   'stat_type': 'TD',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Keyshon Camp',
#   'player_id': 4036051,
#   'season': None,
#   'stat': 3.0,
#   'stat_type': 'TOT',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Phil Campbell',
#   'player_id': 4036052,
#   'season': None,
#   'stat': 8.0,
#   'stat_type': 'TFL',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Keyshon Camp',
#   'player_id': 4036051,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'TFL',
#   'team': 'Pittsburgh'},
#  {'category': 'fumbles',
#   'conference': 'ACC',
#   'player': 'Daniel Carter',
#   'player_id': 4568658,
#   'season': None,
#   'stat': 1.0,
#   'stat_type': 'LOST',
#   'team': 'Pittsburgh'},
#  {'category': 'rushing',
#   'conference': 'ACC',
#   'player': 'Israel Abanikanda',
#   'player_id': 4429202,
#   'season': None,
#   'stat': 28.0,
#   'stat_type': 'CAR',
#   'team': 'Pittsburgh'},
#  {'category': 'receiving',
#   'conference': 'ACC',
#   'player': 'Jaylon Barden',
#   'player_id': 4429247,
#   'season': None,
#   'stat': 20.0,
#   'stat_type': 'YPR',
#   'team': 'Pittsburgh'},
#  {'category': 'puntReturns',
#   'conference': 'ACC',
#   'player': 'DJ Turner',
#   'player_id': 4036211,
#   'season': None,
#   'stat': 8.3,
#   'stat_type': 'AVG',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Dayon Hayes',
#   'player_id': 4429920,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'TD',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Bangally Kamara',
#   'player_id': 4432325,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'QB HUR',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Rashad Battle',
#   'player_id': 4429256,
#   'season': None,
#   'stat': 5.0,
#   'stat_type': 'SOLO',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Deandre Jules',
#   'player_id': 4427650,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'PD',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Cam Bright',
#   'player_id': 4240713,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'TD',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'DJ Turner',
#   'player_id': 4036211,
#   'season': None,
#   'stat': 2.0,
#   'stat_type': 'TFL',
#   'team': 'Pittsburgh'},
#  {'category': 'passing',
#   'conference': 'ACC',
#   'player': 'Joey Yellen',
#   'player_id': 4426360,
#   'season': None,
#   'stat': 78.0,
#   'stat_type': 'ATT',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'A.J. Roberts',
#   'player_id': 4689572,
#   'season': None,
#   'stat': 1.0,
#   'stat_type': 'SOLO',
#   'team': 'Pittsburgh'},
#  {'category': 'receiving',
#   'conference': 'ACC',
#   'player': 'Gavin Thomson',
#   'player_id': 4574964,
#   'season': None,
#   'stat': 6.0,
#   'stat_type': 'YPR',
#   'team': 'Pittsburgh'},
#  {'category': 'rushing',
#   'conference': 'ACC',
#   'player': 'Shocky Jacques-Louis',
#   'player_id': 4361732,
#   'season': None,
#   'stat': 8.0,
#   'stat_type': 'LONG',
#   'team': 'Pittsburgh'},
#  {'category': 'interceptions',
#   'conference': 'ACC',
#   'player': 'A.J. Woods',
#   'player_id': 4428932,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'TD',
#   'team': 'Pittsburgh'},
#  {'category': 'rushing',
#   'conference': 'ACC',
#   'player': ' Team',
#   'player_id': -7111,
#   'season': None,
#   'stat': 6.0,
#   'stat_type': 'CAR',
#   'team': 'Pittsburgh'},
#  {'category': 'receiving',
#   'conference': 'ACC',
#   'player': 'Kyi Wright',
#   'player_id': 4428940,
#   'season': None,
#   'stat': 3.0,
#   'stat_type': 'REC',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Jared Wayne',
#   'player_id': 4430681,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'QB HUR',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Todd Sibley Jr.',
#   'player_id': 4240711,
#   'season': None,
#   'stat': 1.0,
#   'stat_type': 'TOT',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'David Green',
#   'player_id': 4373311,
#   'season': None,
#   'stat': 5.0,
#   'stat_type': 'SOLO',
#   'team': 'Pittsburgh'},
#  {'category': 'fumbles',
#   'conference': 'ACC',
#   'player': 'Vincent Davis',
#   'player_id': 4568660,
#   'season': None,
#   'stat': 2.0,
#   'stat_type': 'FUM',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Brandon Hill',
#   'player_id': 4568662,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'SACKS',
#   'team': 'Pittsburgh'},
#  {'category': 'receiving',
#   'conference': 'ACC',
#   'player': 'Garrett Bickhart',
#   'player_id': 4260169,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'TD',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Erick Hallett',
#   'player_id': 4373320,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'QB HUR',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'A.J. Woods',
#   'player_id': 4428932,
#   'season': None,
#   'stat': 15.0,
#   'stat_type': 'SOLO',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Wendell Davis',
#   'player_id': 4373324,
#   'season': None,
#   'stat': 3.0,
#   'stat_type': 'SOLO',
#   'team': 'Pittsburgh'},
#  {'category': 'passing',
#   'conference': 'ACC',
#   'player': 'Joey Yellen',
#   'player_id': 4426360,
#   'season': None,
#   'stat': 5.2,
#   'stat_type': 'YPA',
#   'team': 'Pittsburgh'},
#  {'category': 'kickReturns',
#   'conference': 'ACC',
#   'player': 'Jordan Addison',
#   'player_id': 4429205,
#   'season': None,
#   'stat': 20.0,
#   'stat_type': 'LONG',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Wendell Davis',
#   'player_id': 4373324,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'TD',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Carson Van Lynn',
#   'player_id': 4240721,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'PD',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Shocky Jacques-Louis',
#   'player_id': 4361732,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'TD',
#   'team': 'Pittsburgh'},
#  {'category': 'rushing',
#   'conference': 'ACC',
#   'player': 'Brandon Hill',
#   'player_id': 4568662,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'TD',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Kenny Pickett',
#   'player_id': 4240703,
#   'season': None,
#   'stat': 1.0,
#   'stat_type': 'SOLO',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Brandon George',
#   'player_id': 4568661,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'TD',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'A.J. Davis',
#   'player_id': 4240710,
#   'season': None,
#   'stat': 1.0,
#   'stat_type': 'TOT',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Habakkuk Baldonado',
#   'player_id': 4373335,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'QB HUR',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Bam Brima',
#   'player_id': 4426774,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'SACKS',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Bam Brima',
#   'player_id': 4426774,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'QB HUR',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Bam Brima',
#   'player_id': 4426774,
#   'season': None,
#   'stat': 1.0,
#   'stat_type': 'SOLO',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Cam Bright',
#   'player_id': 4240713,
#   'season': None,
#   'stat': 31.0,
#   'stat_type': 'SOLO',
#   'team': 'Pittsburgh'},
#  {'category': 'receiving',
#   'conference': 'ACC',
#   'player': 'Jared Wayne',
#   'player_id': 4430681,
#   'season': None,
#   'stat': 15.5,
#   'stat_type': 'YPR',
#   'team': 'Pittsburgh'},
#  {'category': 'rushing',
#   'conference': 'ACC',
#   'player': 'A.J. Davis',
#   'player_id': 4240710,
#   'season': None,
#   'stat': 266.0,
#   'stat_type': 'YDS',
#   'team': 'Pittsburgh'},
#  {'category': 'fumbles',
#   'conference': 'ACC',
#   'player': 'DJ Turner',
#   'player_id': 4036211,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'REC',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Patrick Jones II',
#   'player_id': 4036063,
#   'season': None,
#   'stat': 12.5,
#   'stat_type': 'TFL',
#   'team': 'Pittsburgh'},
#  {'category': 'fumbles',
#   'conference': 'ACC',
#   'player': 'Jared Wayne',
#   'player_id': 4430681,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'REC',
#   'team': 'Pittsburgh'},
#  {'category': 'receiving',
#   'conference': 'ACC',
#   'player': 'Paris Brown',
#   'player_id': 4426797,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'TD',
#   'team': 'Pittsburgh'},
#  {'category': 'fumbles',
#   'conference': 'ACC',
#   'player': 'Noah Palmer',
#   'player_id': 4373326,
#   'season': None,
#   'stat': 1.0,
#   'stat_type': 'FUM',
#   'team': 'Pittsburgh'},
#  {'category': 'fumbles',
#   'conference': 'ACC',
#   'player': 'DJ Turner',
#   'player_id': 4036211,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'LOST',
#   'team': 'Pittsburgh'},
#  {'category': 'kicking',
#   'conference': 'ACC',
#   'player': 'Alex Kessman',
#   'player_id': 4046164,
#   'season': None,
#   'stat': 31.0,
#   'stat_type': 'XPM',
#   'team': 'Pittsburgh'},
#  {'category': 'receiving',
#   'conference': 'ACC',
#   'player': 'Kyi Wright',
#   'player_id': 4428940,
#   'season': None,
#   'stat': 11.3,
#   'stat_type': 'YPR',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Phil Campbell',
#   'player_id': 4036052,
#   'season': None,
#   'stat': 22.0,
#   'stat_type': 'SOLO',
#   'team': 'Pittsburgh'},
#  {'category': 'interceptions',
#   'conference': 'ACC',
#   'player': 'Brandon Hill',
#   'player_id': 4568662,
#   'season': None,
#   'stat': 1.0,
#   'stat_type': 'TD',
#   'team': 'Pittsburgh'},
#  {'category': 'rushing',
#   'conference': 'ACC',
#   'player': 'DJ Turner',
#   'player_id': 4036211,
#   'season': None,
#   'stat': 65.0,
#   'stat_type': 'YDS',
#   'team': 'Pittsburgh'},
#  {'category': 'receiving',
#   'conference': 'ACC',
#   'player': 'Gavin Thomson',
#   'player_id': 4574964,
#   'season': None,
#   'stat': 12.0,
#   'stat_type': 'YDS',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Tyler Bentley',
#   'player_id': 4373328,
#   'season': None,
#   'stat': 5.0,
#   'stat_type': 'SOLO',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Phil Campbell',
#   'player_id': 4036052,
#   'season': None,
#   'stat': 2.0,
#   'stat_type': 'QB HUR',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Cam Bright',
#   'player_id': 4240713,
#   'season': None,
#   'stat': 4.5,
#   'stat_type': 'SACKS',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Patrick Jones II',
#   'player_id': 4036063,
#   'season': None,
#   'stat': 8.5,
#   'stat_type': 'SACKS',
#   'team': 'Pittsburgh'},
#  {'category': 'rushing',
#   'conference': 'ACC',
#   'player': 'Vincent Davis',
#   'player_id': 4568660,
#   'season': None,
#   'stat': 626.0,
#   'stat_type': 'YDS',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Todd Sibley Jr.',
#   'player_id': 4240711,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'QB HUR',
#   'team': 'Pittsburgh'},
#  {'category': 'passing',
#   'conference': 'ACC',
#   'player': 'Kenny Pickett',
#   'player_id': 4240703,
#   'season': None,
#   'stat': 333.0,
#   'stat_type': 'ATT',
#   'team': 'Pittsburgh'},
#  {'category': 'fumbles',
#   'conference': 'ACC',
#   'player': 'Jared Wayne',
#   'player_id': 4430681,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'LOST',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'John Petrishen',
#   'player_id': 3929651,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'SACKS',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Devin Danielson',
#   'player_id': 4373336,
#   'season': None,
#   'stat': 1.0,
#   'stat_type': 'QB HUR',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Carson Van Lynn',
#   'player_id': 4240721,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'TD',
#   'team': 'Pittsburgh'},
#  {'category': 'receiving',
#   'conference': 'ACC',
#   'player': 'Tre Tipton',
#   'player_id': 3895797,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'TD',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Shocky Jacques-Louis',
#   'player_id': 4361732,
#   'season': None,
#   'stat': 2.0,
#   'stat_type': 'TOT',
#   'team': 'Pittsburgh'},
#  {'category': 'receiving',
#   'conference': 'ACC',
#   'player': 'Israel Abanikanda',
#   'player_id': 4429202,
#   'season': None,
#   'stat': 1.0,
#   'stat_type': 'TD',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Nate Temple',
#   'player_id': 4428652,
#   'season': None,
#   'stat': 1.0,
#   'stat_type': 'PD',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Bangally Kamara',
#   'player_id': 4432325,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'SACKS',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Patrick Jones II',
#   'player_id': 4036063,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'TD',
#   'team': 'Pittsburgh'},
#  {'category': 'receiving',
#   'conference': 'ACC',
#   'player': 'Kyi Wright',
#   'player_id': 4428940,
#   'season': None,
#   'stat': 16.0,
#   'stat_type': 'LONG',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Tre Tipton',
#   'player_id': 3895797,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'QB HUR',
#   'team': 'Pittsburgh'},
#  {'category': 'receiving',
#   'conference': 'ACC',
#   'player': 'Tre Tipton',
#   'player_id': 3895797,
#   'season': None,
#   'stat': 20.0,
#   'stat_type': 'LONG',
#   'team': 'Pittsburgh'},
#  {'category': 'passing',
#   'conference': 'ACC',
#   'player': 'Joey Yellen',
#   'player_id': 4426360,
#   'season': None,
#   'stat': 402.0,
#   'stat_type': 'YDS',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'A.J. Roberts',
#   'player_id': 4689572,
#   'season': None,
#   'stat': 1.0,
#   'stat_type': 'TOT',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Todd Sibley Jr.',
#   'player_id': 4240711,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'SACKS',
#   'team': 'Pittsburgh'},
#  {'category': 'receiving',
#   'conference': 'ACC',
#   'player': 'Vincent Davis',
#   'player_id': 4568660,
#   'season': None,
#   'stat': 152.0,
#   'stat_type': 'YDS',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Paris Ford',
#   'player_id': 4240705,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'SACKS',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Bam Brima',
#   'player_id': 4426774,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'PD',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'A.J. Davis',
#   'player_id': 4240710,
#   'season': None,
#   'stat': 1.0,
#   'stat_type': 'SOLO',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'John Petrishen',
#   'player_id': 3929651,
#   'season': None,
#   'stat': 1.5,
#   'stat_type': 'TFL',
#   'team': 'Pittsburgh'},
#  {'category': 'rushing',
#   'conference': 'ACC',
#   'player': 'Kenny Pickett',
#   'player_id': 4240703,
#   'season': None,
#   'stat': 2.0,
#   'stat_type': 'YPC',
#   'team': 'Pittsburgh'},
#  {'category': 'receiving',
#   'conference': 'ACC',
#   'player': 'John Vardzel',
#   'player_id': 4373334,
#   'season': None,
#   'stat': 1.0,
#   'stat_type': 'REC',
#   'team': 'Pittsburgh'},
#  {'category': 'receiving',
#   'conference': 'ACC',
#   'player': 'Vincent Davis',
#   'player_id': 4568660,
#   'season': None,
#   'stat': 1.0,
#   'stat_type': 'TD',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Brandon Hill',
#   'player_id': 4568662,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'QB HUR',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Judson Tallandier',
#   'player_id': 4373319,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'QB HUR',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Jared Campbell',
#   'player_id': 4574972,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'TD',
#   'team': 'Pittsburgh'},
#  {'category': 'receiving',
#   'conference': 'ACC',
#   'player': 'Tre Tipton',
#   'player_id': 3895797,
#   'season': None,
#   'stat': 11.0,
#   'stat_type': 'REC',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': ' Team',
#   'player_id': -7111,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'QB HUR',
#   'team': 'Pittsburgh'},
#  {'category': 'receiving',
#   'conference': 'ACC',
#   'player': 'Daniel Moraga',
#   'player_id': 4242999,
#   'season': None,
#   'stat': 5.0,
#   'stat_type': 'REC',
#   'team': 'Pittsburgh'},
#  {'category': 'puntReturns',
#   'conference': 'ACC',
#   'player': 'Jordan Addison',
#   'player_id': 4429205,
#   'season': None,
#   'stat': 15.0,
#   'stat_type': 'YDS',
#   'team': 'Pittsburgh'},
#  {'category': 'receiving',
#   'conference': 'ACC',
#   'player': 'Israel Abanikanda',
#   'player_id': 4429202,
#   'season': None,
#   'stat': 11.0,
#   'stat_type': 'YDS',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Todd Sibley Jr.',
#   'player_id': 4240711,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'TFL',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Damar Hamlin',
#   'player_id': 4036060,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'QB HUR',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Jared Campbell',
#   'player_id': 4574972,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'PD',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'A.J. Davis',
#   'player_id': 4240710,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'TD',
#   'team': 'Pittsburgh'},
#  {'category': 'rushing',
#   'conference': 'ACC',
#   'player': 'A.J. Davis',
#   'player_id': 4240710,
#   'season': None,
#   'stat': 31.0,
#   'stat_type': 'LONG',
#   'team': 'Pittsburgh'},
#  {'category': 'punting',
#   'conference': 'ACC',
#   'player': 'Kirk Christodoulou',
#   'player_id': 4240729,
#   'season': None,
#   'stat': 23.0,
#   'stat_type': 'In 20',
#   'team': 'Pittsburgh'},
#  {'category': 'kicking',
#   'conference': 'ACC',
#   'player': 'Alex Kessman',
#   'player_id': 4046164,
#   'season': None,
#   'stat': 100.0,
#   'stat_type': 'PTS',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Devin Danielson',
#   'player_id': 4373336,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'TD',
#   'team': 'Pittsburgh'},
#  {'category': 'receiving',
#   'conference': 'ACC',
#   'player': 'Paris Brown',
#   'player_id': 4426797,
#   'season': None,
#   'stat': 2.0,
#   'stat_type': 'YDS',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Brandon Hill',
#   'player_id': 4568662,
#   'season': None,
#   'stat': 24.0,
#   'stat_type': 'TOT',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Jason Pinnock',
#   'player_id': 4240706,
#   'season': None,
#   'stat': 5.0,
#   'stat_type': 'PD',
#   'team': 'Pittsburgh'},
#  {'category': 'puntReturns',
#   'conference': 'ACC',
#   'player': 'Brandon George',
#   'player_id': 4568661,
#   'season': None,
#   'stat': 14.0,
#   'stat_type': 'LONG',
#   'team': 'Pittsburgh'},
#  {'category': 'rushing',
#   'conference': 'ACC',
#   'player': 'Daniel Carter',
#   'player_id': 4568658,
#   'season': None,
#   'stat': 14.0,
#   'stat_type': 'CAR',
#   'team': 'Pittsburgh'},
#  {'category': 'passing',
#   'conference': 'ACC',
#   'player': 'Davis Beville',
#   'player_id': 4428887,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'TD',
#   'team': 'Pittsburgh'},
#  {'category': 'rushing',
#   'conference': 'ACC',
#   'player': 'Jordan Addison',
#   'player_id': 4429205,
#   'season': None,
#   'stat': 58.0,
#   'stat_type': 'YDS',
#   'team': 'Pittsburgh'},
#  {'category': 'receiving',
#   'conference': 'ACC',
#   'player': 'Jaylon Barden',
#   'player_id': 4429247,
#   'season': None,
#   'stat': 7.0,
#   'stat_type': 'REC',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Habakkuk Baldonado',
#   'player_id': 4373335,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'TD',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Deslin Alexandre',
#   'player_id': 4240728,
#   'season': None,
#   'stat': 1.0,
#   'stat_type': 'QB HUR',
#   'team': 'Pittsburgh'},
#  {'category': 'fumbles',
#   'conference': 'ACC',
#   'player': 'Kenny Pickett',
#   'player_id': 4240703,
#   'season': None,
#   'stat': 1.0,
#   'stat_type': 'LOST',
#   'team': 'Pittsburgh'},
#  {'category': 'kickReturns',
#   'conference': 'ACC',
#   'player': 'Jordan Addison',
#   'player_id': 4429205,
#   'season': None,
#   'stat': 39.0,
#   'stat_type': 'YDS',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Jordan Addison',
#   'player_id': 4429205,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'PD',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'A.J. Woods',
#   'player_id': 4428932,
#   'season': None,
#   'stat': 1.0,
#   'stat_type': 'TFL',
#   'team': 'Pittsburgh'},
#  {'category': 'rushing',
#   'conference': 'ACC',
#   'player': 'Shocky Jacques-Louis',
#   'player_id': 4361732,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'TD',
#   'team': 'Pittsburgh'},
#  {'category': 'fumbles',
#   'conference': 'ACC',
#   'player': 'Daniel Carter',
#   'player_id': 4568658,
#   'season': None,
#   'stat': 1.0,
#   'stat_type': 'FUM',
#   'team': 'Pittsburgh'},
#  {'category': 'rushing',
#   'conference': 'ACC',
#   'player': 'Jordan Addison',
#   'player_id': 4429205,
#   'season': None,
#   'stat': 6.4,
#   'stat_type': 'YPC',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Deandre Jules',
#   'player_id': 4427650,
#   'season': None,
#   'stat': 1.5,
#   'stat_type': 'TFL',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Rashad Weaver',
#   'player_id': 4036076,
#   'season': None,
#   'stat': 14.0,
#   'stat_type': 'TFL',
#   'team': 'Pittsburgh'},
#  {'category': 'rushing',
#   'conference': 'ACC',
#   'player': 'Davis Beville',
#   'player_id': 4428887,
#   'season': None,
#   'stat': -2.3,
#   'stat_type': 'YPC',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Calijah Kancey',
#   'player_id': 4427673,
#   'season': None,
#   'stat': 12.0,
#   'stat_type': 'SOLO',
#   'team': 'Pittsburgh'},
#  {'category': 'receiving',
#   'conference': 'ACC',
#   'player': 'Jordan Addison',
#   'player_id': 4429205,
#   'season': None,
#   'stat': 11.1,
#   'stat_type': 'YPR',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Jordan Addison',
#   'player_id': 4429205,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'QB HUR',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Blake Zubovic',
#   'player_id': 4373332,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'PD',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Buddy Mack III',
#   'player_id': 4689567,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'TFL',
#   'team': 'Pittsburgh'},
#  {'category': 'kicking',
#   'conference': 'ACC',
#   'player': 'Ben Sauls',
#   'player_id': 4566158,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'LONG',
#   'team': 'Pittsburgh'},
#  {'category': 'fumbles',
#   'conference': 'ACC',
#   'player': 'Nick Patti',
#   'player_id': 4373314,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'REC',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': ' Team',
#   'player_id': -7111,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'PD',
#   'team': 'Pittsburgh'},
#  {'category': 'receiving',
#   'conference': 'ACC',
#   'player': 'Jake Zilinskas',
#   'player_id': 4240709,
#   'season': None,
#   'stat': 14.0,
#   'stat_type': 'YPR',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Noah Palmer',
#   'player_id': 4373326,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'QB HUR',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Nate Temple',
#   'player_id': 4428652,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'TD',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Chris Maloney',
#   'player_id': 4373337,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'TFL',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Judson Tallandier',
#   'player_id': 4373319,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'SACKS',
#   'team': 'Pittsburgh'},
#  {'category': 'kickReturns',
#   'conference': 'ACC',
#   'player': 'Vincent Davis',
#   'player_id': 4568660,
#   'season': None,
#   'stat': 20.0,
#   'stat_type': 'AVG',
#   'team': 'Pittsburgh'},
#  {'category': 'kicking',
#   'conference': 'ACC',
#   'player': 'Alex Kessman',
#   'player_id': 4046164,
#   'season': None,
#   'stat': 32.0,
#   'stat_type': 'XPA',
#   'team': 'Pittsburgh'},
#  {'category': 'receiving',
#   'conference': 'ACC',
#   'player': 'Taysir Mack',
#   'player_id': 4045291,
#   'season': None,
#   'stat': 40.0,
#   'stat_type': 'LONG',
#   'team': 'Pittsburgh'},
#  {'category': 'rushing',
#   'conference': 'ACC',
#   'player': 'Davis Beville',
#   'player_id': 4428887,
#   'season': None,
#   'stat': -9.0,
#   'stat_type': 'YDS',
#   'team': 'Pittsburgh'},
#  {'category': 'kickReturns',
#   'conference': 'ACC',
#   'player': 'DJ Turner',
#   'player_id': 4036211,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'TD',
#   'team': 'Pittsburgh'},
#  {'category': 'receiving',
#   'conference': 'ACC',
#   'player': 'Lucas Krull',
#   'player_id': 4360231,
#   'season': None,
#   'stat': 6.0,
#   'stat_type': 'YDS',
#   'team': 'Pittsburgh'},
#  {'category': 'interceptions',
#   'conference': 'ACC',
#   'player': 'Paris Ford',
#   'player_id': 4240705,
#   'season': None,
#   'stat': 11.7,
#   'stat_type': 'AVG',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'A.J. Roberts',
#   'player_id': 4689572,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'TFL',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Paris Brown',
#   'player_id': 4426797,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'TD',
#   'team': 'Pittsburgh'},
#  {'category': 'interceptions',
#   'conference': 'ACC',
#   'player': 'Jason Pinnock',
#   'player_id': 4240706,
#   'season': None,
#   'stat': 20.0,
#   'stat_type': 'YDS',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Rashad Weaver',
#   'player_id': 4036076,
#   'season': None,
#   'stat': 2.0,
#   'stat_type': 'PD',
#   'team': 'Pittsburgh'},
#  {'category': 'interceptions',
#   'conference': 'ACC',
#   'player': 'A.J. Woods',
#   'player_id': 4428932,
#   'season': None,
#   'stat': 1.0,
#   'stat_type': 'INT',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Cal Adomitis',
#   'player_id': 4240719,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'QB HUR',
#   'team': 'Pittsburgh'},
#  {'category': 'kickReturns',
#   'conference': 'ACC',
#   'player': 'Vincent Davis',
#   'player_id': 4568660,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'TD',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Marquis Williams',
#   'player_id': 4373315,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'SACKS',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Bangally Kamara',
#   'player_id': 4432325,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'TFL',
#   'team': 'Pittsburgh'},
#  {'category': 'receiving',
#   'conference': 'ACC',
#   'player': 'Vincent Davis',
#   'player_id': 4568660,
#   'season': None,
#   'stat': 19.0,
#   'stat_type': 'LONG',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Dayon Hayes',
#   'player_id': 4429920,
#   'season': None,
#   'stat': 3.0,
#   'stat_type': 'TOT',
#   'team': 'Pittsburgh'},
#  {'category': 'fumbles',
#   'conference': 'ACC',
#   'player': 'A.J. Davis',
#   'player_id': 4240710,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'FUM',
#   'team': 'Pittsburgh'},
#  {'category': 'rushing',
#   'conference': 'ACC',
#   'player': 'Kenny Pickett',
#   'player_id': 4240703,
#   'season': None,
#   'stat': 81.0,
#   'stat_type': 'CAR',
#   'team': 'Pittsburgh'},
#  {'category': 'interceptions',
#   'conference': 'ACC',
#   'player': 'Erick Hallett',
#   'player_id': 4373320,
#   'season': None,
#   'stat': -1.5,
#   'stat_type': 'AVG',
#   'team': 'Pittsburgh'},
#  {'category': 'interceptions',
#   'conference': 'ACC',
#   'player': 'A.J. Woods',
#   'player_id': 4428932,
#   'season': None,
#   'stat': -1.0,
#   'stat_type': 'YDS',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Damar Hamlin',
#   'player_id': 4036060,
#   'season': None,
#   'stat': 38.0,
#   'stat_type': 'SOLO',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Keyshon Camp',
#   'player_id': 4036051,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'PD',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Chase Pine',
#   'player_id': 4036070,
#   'season': None,
#   'stat': 7.0,
#   'stat_type': 'TFL',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Judson Tallandier',
#   'player_id': 4373319,
#   'season': None,
#   'stat': 7.0,
#   'stat_type': 'SOLO',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'David Green',
#   'player_id': 4373311,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'TD',
#   'team': 'Pittsburgh'},
#  {'category': 'interceptions',
#   'conference': 'ACC',
#   'player': 'Brandon Hill',
#   'player_id': 4568662,
#   'season': None,
#   'stat': 1.0,
#   'stat_type': 'INT',
#   'team': 'Pittsburgh'},
#  {'category': 'fumbles',
#   'conference': 'ACC',
#   'player': 'Patrick Jones II',
#   'player_id': 4036063,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'LOST',
#   'team': 'Pittsburgh'},
#  {'category': 'rushing',
#   'conference': 'ACC',
#   'player': ' Team',
#   'player_id': -7111,
#   'season': None,
#   'stat': -15.0,
#   'stat_type': 'YDS',
#   'team': 'Pittsburgh'},
#  {'category': 'fumbles',
#   'conference': 'ACC',
#   'player': 'Rashad Weaver',
#   'player_id': 4036076,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'LOST',
#   'team': 'Pittsburgh'},
#  {'category': 'receiving',
#   'conference': 'ACC',
#   'player': 'Jordan Addison',
#   'player_id': 4429205,
#   'season': None,
#   'stat': 60.0,
#   'stat_type': 'REC',
#   'team': 'Pittsburgh'},
#  {'category': 'interceptions',
#   'conference': 'ACC',
#   'player': 'Paris Ford',
#   'player_id': 4240705,
#   'season': None,
#   'stat': 35.0,
#   'stat_type': 'YDS',
#   'team': 'Pittsburgh'},
#  {'category': 'fumbles',
#   'conference': 'ACC',
#   'player': 'A.J. Davis',
#   'player_id': 4240710,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'LOST',
#   'team': 'Pittsburgh'},
#  {'category': 'punting',
#   'conference': 'ACC',
#   'player': 'Kirk Christodoulou',
#   'player_id': 4240729,
#   'season': None,
#   'stat': 2356.0,
#   'stat_type': 'YDS',
#   'team': 'Pittsburgh'},
#  {'category': 'kicking',
#   'conference': 'ACC',
#   'player': 'Ben Sauls',
#   'player_id': 4566158,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'FGA',
#   'team': 'Pittsburgh'},
#  {'category': 'rushing',
#   'conference': 'ACC',
#   'player': 'Daniel Carter',
#   'player_id': 4568658,
#   'season': None,
#   'stat': 4.6,
#   'stat_type': 'YPC',
#   'team': 'Pittsburgh'},
#  {'category': 'rushing',
#   'conference': 'ACC',
#   'player': 'Kenny Pickett',
#   'player_id': 4240703,
#   'season': None,
#   'stat': 18.0,
#   'stat_type': 'LONG',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Tre Tipton',
#   'player_id': 3895797,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'TD',
#   'team': 'Pittsburgh'},
#  {'category': 'receiving',
#   'conference': 'ACC',
#   'player': 'Todd Sibley Jr.',
#   'player_id': 4240711,
#   'season': None,
#   'stat': 7.0,
#   'stat_type': 'YDS',
#   'team': 'Pittsburgh'},
#  {'category': 'passing',
#   'conference': 'ACC',
#   'player': 'Nick Patti',
#   'player_id': 4373314,
#   'season': None,
#   'stat': 0.4,
#   'stat_type': 'PCT',
#   'team': 'Pittsburgh'},
#  {'category': 'rushing',
#   'conference': 'ACC',
#   'player': 'DJ Turner',
#   'player_id': 4036211,
#   'season': None,
#   'stat': 24.0,
#   'stat_type': 'LONG',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'SirVocea Dennis',
#   'player_id': 4429511,
#   'season': None,
#   'stat': 6.0,
#   'stat_type': 'QB HUR',
#   'team': 'Pittsburgh'},
#  {'category': 'receiving',
#   'conference': 'ACC',
#   'player': 'Shocky Jacques-Louis',
#   'player_id': 4361732,
#   'season': None,
#   'stat': 327.0,
#   'stat_type': 'YDS',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Chase Pine',
#   'player_id': 4036070,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'TD',
#   'team': 'Pittsburgh'},
#  {'category': 'passing',
#   'conference': 'ACC',
#   'player': 'Joey Yellen',
#   'player_id': 4426360,
#   'season': None,
#   'stat': 0.449,
#   'stat_type': 'PCT',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Nate Temple',
#   'player_id': 4428652,
#   'season': None,
#   'stat': 2.0,
#   'stat_type': 'TOT',
#   'team': 'Pittsburgh'},
#  {'category': 'receiving',
#   'conference': 'ACC',
#   'player': 'John Vardzel',
#   'player_id': 4373334,
#   'season': None,
#   'stat': 5.0,
#   'stat_type': 'YDS',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Chris Maloney',
#   'player_id': 4373337,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'TOT',
#   'team': 'Pittsburgh'},
#  {'category': 'receiving',
#   'conference': 'ACC',
#   'player': 'Kaymar Mimes',
#   'player_id': 4373339,
#   'season': None,
#   'stat': 4.0,
#   'stat_type': 'YDS',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': ' Team',
#   'player_id': -7111,
#   'season': None,
#   'stat': 1.0,
#   'stat_type': 'TOT',
#   'team': 'Pittsburgh'},
#  {'category': 'rushing',
#   'conference': 'ACC',
#   'player': 'Joey Yellen',
#   'player_id': 4426360,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'LONG',
#   'team': 'Pittsburgh'},
#  {'category': 'receiving',
#   'conference': 'ACC',
#   'player': 'Jaylon Barden',
#   'player_id': 4429247,
#   'season': None,
#   'stat': 140.0,
#   'stat_type': 'YDS',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Blake Zubovic',
#   'player_id': 4373332,
#   'season': None,
#   'stat': 1.0,
#   'stat_type': 'SOLO',
#   'team': 'Pittsburgh'},
#  {'category': 'passing',
#   'conference': 'ACC',
#   'player': 'Davis Beville',
#   'player_id': 4428887,
#   'season': None,
#   'stat': 0.5,
#   'stat_type': 'PCT',
#   'team': 'Pittsburgh'},
#  {'category': 'receiving',
#   'conference': 'ACC',
#   'player': 'Israel Abanikanda',
#   'player_id': 4429202,
#   'season': None,
#   'stat': 5.5,
#   'stat_type': 'YPR',
#   'team': 'Pittsburgh'},
#  {'category': 'rushing',
#   'conference': 'ACC',
#   'player': 'A.J. Davis',
#   'player_id': 4240710,
#   'season': None,
#   'stat': 4.4,
#   'stat_type': 'YPC',
#   'team': 'Pittsburgh'},
#  {'category': 'receiving',
#   'conference': 'ACC',
#   'player': 'John Vardzel',
#   'player_id': 4373334,
#   'season': None,
#   'stat': 5.0,
#   'stat_type': 'LONG',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Kenny Pickett',
#   'player_id': 4240703,
#   'season': None,
#   'stat': 1.0,
#   'stat_type': 'TOT',
#   'team': 'Pittsburgh'},
#  {'category': 'receiving',
#   'conference': 'ACC',
#   'player': 'Garrett Bickhart',
#   'player_id': 4260169,
#   'season': None,
#   'stat': 2.0,
#   'stat_type': 'REC',
#   'team': 'Pittsburgh'},
#  {'category': 'receiving',
#   'conference': 'ACC',
#   'player': 'A.J. Davis',
#   'player_id': 4240710,
#   'season': None,
#   'stat': 45.0,
#   'stat_type': 'YDS',
#   'team': 'Pittsburgh'},
#  {'category': 'receiving',
#   'conference': 'ACC',
#   'player': 'Paris Brown',
#   'player_id': 4426797,
#   'season': None,
#   'stat': 2.0,
#   'stat_type': 'YPR',
#   'team': 'Pittsburgh'},
#  {'category': 'interceptions',
#   'conference': 'ACC',
#   'player': 'Marquis Williams',
#   'player_id': 4373315,
#   'season': None,
#   'stat': 45.0,
#   'stat_type': 'YDS',
#   'team': 'Pittsburgh'},
#  {'category': 'receiving',
#   'conference': 'ACC',
#   'player': 'Daniel Moraga',
#   'player_id': 4242999,
#   'season': None,
#   'stat': 8.4,
#   'stat_type': 'YPR',
#   'team': 'Pittsburgh'},
#  {'category': 'receiving',
# ...
#   'season': None,
#   'stat': 22.0,
#   'stat_type': 'SOLO',
#   'team': 'Pittsburgh'},
#  {'category': 'receiving',
#   'conference': 'ACC',
#   'player': 'Shocky Jacques-Louis',
#   'player_id': 4361732,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'TD',
#   'team': 'Pittsburgh'},
#  {'category': 'rushing',
#   'conference': 'ACC',
#   'player': 'Nick Patti',
#   'player_id': 4373314,
#   'season': None,
#   'stat': 1.6,
#   'stat_type': 'YPC',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Habakkuk Baldonado',
#   'player_id': 4373335,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'SACKS',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Rashad Battle',
#   'player_id': 4429256,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'TFL',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Cal Adomitis',
#   'player_id': 4240719,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'SACKS',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Carson Van Lynn',
#   'player_id': 4240721,
#   'season': None,
#   'stat': 1.0,
#   'stat_type': 'TOT',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Paris Brown',
#   'player_id': 4426797,
#   'season': None,
#   'stat': 2.0,
#   'stat_type': 'TOT',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'John Morgan',
#   'player_id': 4373312,
#   'season': None,
#   'stat': 7.0,
#   'stat_type': 'TFL',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Damar Hamlin',
#   'player_id': 4036060,
#   'season': None,
#   'stat': 7.0,
#   'stat_type': 'PD',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Taysir Mack',
#   'player_id': 4045291,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'PD',
#   'team': 'Pittsburgh'},
#  {'category': 'kickReturns',
#   'conference': 'ACC',
#   'player': 'DJ Turner',
#   'player_id': 4036211,
#   'season': None,
#   'stat': 42.0,
#   'stat_type': 'LONG',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'John Petrishen',
#   'player_id': 3929651,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'TD',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Judson Tallandier',
#   'player_id': 4373319,
#   'season': None,
#   'stat': 8.0,
#   'stat_type': 'TOT',
#   'team': 'Pittsburgh'},
#  {'category': 'rushing',
#   'conference': 'ACC',
#   'player': 'Nick Patti',
#   'player_id': 4373314,
#   'season': None,
#   'stat': 13.0,
#   'stat_type': 'LONG',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Todd Sibley Jr.',
#   'player_id': 4240711,
#   'season': None,
#   'stat': 1.0,
#   'stat_type': 'TD',
#   'team': 'Pittsburgh'},
#  {'category': 'receiving',
#   'conference': 'ACC',
#   'player': 'Tre Tipton',
#   'player_id': 3895797,
#   'season': None,
#   'stat': 9.5,
#   'stat_type': 'YPR',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Dayon Hayes',
#   'player_id': 4429920,
#   'season': None,
#   'stat': 2.5,
#   'stat_type': 'SACKS',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Cal Adomitis',
#   'player_id': 4240719,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'PD',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'David Green',
#   'player_id': 4373311,
#   'season': None,
#   'stat': 2.0,
#   'stat_type': 'TFL',
#   'team': 'Pittsburgh'},
#  {'category': 'passing',
#   'conference': 'ACC',
#   'player': 'Kenny Pickett',
#   'player_id': 4240703,
#   'season': None,
#   'stat': 13.0,
#   'stat_type': 'TD',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Jared Campbell',
#   'player_id': 4574972,
#   'season': None,
#   'stat': 0.5,
#   'stat_type': 'TFL',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Devin Danielson',
#   'player_id': 4373336,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'PD',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Marquis Williams',
#   'player_id': 4373315,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'TD',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'DJ Turner',
#   'player_id': 4036211,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'TD',
#   'team': 'Pittsburgh'},
#  {'category': 'receiving',
#   'conference': 'ACC',
#   'player': 'Tre Tipton',
#   'player_id': 3895797,
#   'season': None,
#   'stat': 104.0,
#   'stat_type': 'YDS',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Tyler Bentley',
#   'player_id': 4373328,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'TD',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Noah Palmer',
#   'player_id': 4373326,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'SACKS',
#   'team': 'Pittsburgh'},
#  {'category': 'fumbles',
#   'conference': 'ACC',
#   'player': 'Kenny Pickett',
#   'player_id': 4240703,
#   'season': None,
#   'stat': 7.0,
#   'stat_type': 'FUM',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Buddy Mack III',
#   'player_id': 4689567,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'SACKS',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': ' Team',
#   'player_id': -7111,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'TD',
#   'team': 'Pittsburgh'},
#  {'category': 'kicking',
#   'conference': 'ACC',
#   'player': 'Ben Sauls',
#   'player_id': 4566158,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'FGM',
#   'team': 'Pittsburgh'},
#  {'category': 'fumbles',
#   'conference': 'ACC',
#   'player': 'Daniel Carter',
#   'player_id': 4568658,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'REC',
#   'team': 'Pittsburgh'},
#  {'category': 'rushing',
#   'conference': 'ACC',
#   'player': 'Jordan Addison',
#   'player_id': 4429205,
#   'season': None,
#   'stat': 9.0,
#   'stat_type': 'CAR',
#   'team': 'Pittsburgh'},
#  {'category': 'receiving',
#   'conference': 'ACC',
#   'player': 'Todd Sibley Jr.',
#   'player_id': 4240711,
#   'season': None,
#   'stat': 1.0,
#   'stat_type': 'REC',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': ' Team',
#   'player_id': -7111,
#   'season': None,
#   'stat': 1.0,
#   'stat_type': 'SOLO',
#   'team': 'Pittsburgh'},
#  {'category': 'rushing',
#   'conference': 'ACC',
#   'player': 'Jordan Addison',
#   'player_id': 4429205,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'TD',
#   'team': 'Pittsburgh'},
#  {'category': 'kickReturns',
#   'conference': 'ACC',
#   'player': 'DJ Turner',
#   'player_id': 4036211,
#   'season': None,
#   'stat': 311.0,
#   'stat_type': 'YDS',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Patrick Jones II',
#   'player_id': 4036063,
#   'season': None,
#   'stat': 42.0,
#   'stat_type': 'TOT',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Blake Zubovic',
#   'player_id': 4373332,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'TFL',
#   'team': 'Pittsburgh'},
#  {'category': 'puntReturns',
#   'conference': 'ACC',
#   'player': 'Todd Sibley Jr.',
#   'player_id': 4240711,
#   'season': None,
#   'stat': 1.0,
#   'stat_type': 'TD',
#   'team': 'Pittsburgh'},
#  {'category': 'puntReturns',
#   'conference': 'ACC',
#   'player': 'Todd Sibley Jr.',
#   'player_id': 4240711,
#   'season': None,
#   'stat': 25.0,
#   'stat_type': 'YDS',
#   'team': 'Pittsburgh'},
#  {'category': 'rushing',
#   'conference': 'ACC',
#   'player': 'Daniel Carter',
#   'player_id': 4568658,
#   'season': None,
#   'stat': 1.0,
#   'stat_type': 'TD',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'SirVocea Dennis',
#   'player_id': 4429511,
#   'season': None,
#   'stat': 14.0,
#   'stat_type': 'TFL',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Deslin Alexandre',
#   'player_id': 4240728,
#   'season': None,
#   'stat': 2.0,
#   'stat_type': 'PD',
#   'team': 'Pittsburgh'},
#  {'category': 'rushing',
#   'conference': 'ACC',
#   'player': 'Kenny Pickett',
#   'player_id': 4240703,
#   'season': None,
#   'stat': 162.0,
#   'stat_type': 'YDS',
#   'team': 'Pittsburgh'},
#  {'category': 'fumbles',
#   'conference': 'ACC',
#   'player': 'Nick Patti',
#   'player_id': 4373314,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'LOST',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Nate Temple',
#   'player_id': 4428652,
#   'season': None,
#   'stat': 1.0,
#   'stat_type': 'SOLO',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Calijah Kancey',
#   'player_id': 4427673,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'TD',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Taysir Mack',
#   'player_id': 4045291,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'SOLO',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Judson Tallandier',
#   'player_id': 4373319,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'TD',
#   'team': 'Pittsburgh'},
#  {'category': 'rushing',
#   'conference': 'ACC',
#   'player': 'Vincent Davis',
#   'player_id': 4568660,
#   'season': None,
#   'stat': 6.0,
#   'stat_type': 'TD',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'John Morgan',
#   'player_id': 4373312,
#   'season': None,
#   'stat': 8.0,
#   'stat_type': 'SOLO',
#   'team': 'Pittsburgh'},
#  {'category': 'receiving',
#   'conference': 'ACC',
#   'player': 'A.J. Davis',
#   'player_id': 4240710,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'TD',
#   'team': 'Pittsburgh'},
#  {'category': 'passing',
#   'conference': 'ACC',
#   'player': 'Davis Beville',
#   'player_id': 4428887,
#   'season': None,
#   'stat': 10.0,
#   'stat_type': 'ATT',
#   'team': 'Pittsburgh'},
#  {'category': 'passing',
#   'conference': 'ACC',
#   'player': 'Nick Patti',
#   'player_id': 4373314,
#   'season': None,
#   'stat': 2.0,
#   'stat_type': 'COMPLETIONS',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Marquis Williams',
#   'player_id': 4373315,
#   'season': None,
#   'stat': 4.0,
#   'stat_type': 'PD',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Jared Wayne',
#   'player_id': 4430681,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'TD',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Tyler Bentley',
#   'player_id': 4373328,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'QB HUR',
#   'team': 'Pittsburgh'},
#  {'category': 'kickReturns',
#   'conference': 'ACC',
#   'player': 'Vincent Davis',
#   'player_id': 4568660,
#   'season': None,
#   'stat': 20.0,
#   'stat_type': 'YDS',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Buddy Mack III',
#   'player_id': 4689567,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'PD',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'DJ Turner',
#   'player_id': 4036211,
#   'season': None,
#   'stat': 3.0,
#   'stat_type': 'SOLO',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'DJ Turner',
#   'player_id': 4036211,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'SACKS',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Calijah Kancey',
#   'player_id': 4427673,
#   'season': None,
#   'stat': 7.0,
#   'stat_type': 'TFL',
#   'team': 'Pittsburgh'},
#  {'category': 'rushing',
#   'conference': 'ACC',
#   'player': 'Todd Sibley Jr.',
#   'player_id': 4240711,
#   'season': None,
#   'stat': 54.0,
#   'stat_type': 'YDS',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Nate Temple',
#   'player_id': 4428652,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'SACKS',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Devin Danielson',
#   'player_id': 4373336,
#   'season': None,
#   'stat': 2.5,
#   'stat_type': 'SACKS',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Erick Hallett',
#   'player_id': 4373320,
#   'season': None,
#   'stat': 2.0,
#   'stat_type': 'TFL',
#   'team': 'Pittsburgh'},
#  {'category': 'receiving',
#   'conference': 'ACC',
#   'player': 'DJ Turner',
#   'player_id': 4036211,
#   'season': None,
#   'stat': 64.0,
#   'stat_type': 'LONG',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Cam Bright',
#   'player_id': 4240713,
#   'season': None,
#   'stat': 50.0,
#   'stat_type': 'TOT',
#   'team': 'Pittsburgh'},
#  {'category': 'fumbles',
#   'conference': 'ACC',
#   'player': 'Joey Yellen',
#   'player_id': 4426360,
#   'season': None,
#   'stat': 1.0,
#   'stat_type': 'LOST',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Blake Zubovic',
#   'player_id': 4373332,
#   'season': None,
#   'stat': 1.0,
#   'stat_type': 'TOT',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Carson Van Lynn',
#   'player_id': 4240721,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'SOLO',
#   'team': 'Pittsburgh'},
#  {'category': 'puntReturns',
#   'conference': 'ACC',
#   'player': 'Brandon George',
#   'player_id': 4568661,
#   'season': None,
#   'stat': 14.0,
#   'stat_type': 'AVG',
#   'team': 'Pittsburgh'},
#  {'category': 'receiving',
#   'conference': 'ACC',
#   'player': 'Taysir Mack',
#   'player_id': 4045291,
#   'season': None,
#   'stat': 13.3,
#   'stat_type': 'YPR',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Shocky Jacques-Louis',
#   'player_id': 4361732,
#   'season': None,
#   'stat': 2.0,
#   'stat_type': 'SOLO',
#   'team': 'Pittsburgh'},
#  {'category': 'punting',
#   'conference': 'ACC',
#   'player': ' Team',
#   'player_id': -7111,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'YDS',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Tyler Bentley',
#   'player_id': 4373328,
#   'season': None,
#   'stat': 2.0,
#   'stat_type': 'TFL',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'A.J. Davis',
#   'player_id': 4240710,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'QB HUR',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Bangally Kamara',
#   'player_id': 4432325,
#   'season': None,
#   'stat': 3.0,
#   'stat_type': 'SOLO',
#   'team': 'Pittsburgh'},
#  {'category': 'rushing',
#   'conference': 'ACC',
#   'player': 'Israel Abanikanda',
#   'player_id': 4429202,
#   'season': None,
#   'stat': 95.0,
#   'stat_type': 'YDS',
#   'team': 'Pittsburgh'},
#  {'category': 'rushing',
#   'conference': 'ACC',
#   'player': 'Shocky Jacques-Louis',
#   'player_id': 4361732,
#   'season': None,
#   'stat': 10.0,
#   'stat_type': 'YDS',
#   'team': 'Pittsburgh'},
#  {'category': 'interceptions',
#   'conference': 'ACC',
#   'player': 'Damar Hamlin',
#   'player_id': 4036060,
#   'season': None,
#   'stat': 2.0,
#   'stat_type': 'INT',
#   'team': 'Pittsburgh'},
#  {'category': 'interceptions',
#   'conference': 'ACC',
#   'player': 'Marquis Williams',
#   'player_id': 4373315,
#   'season': None,
#   'stat': 22.5,
#   'stat_type': 'AVG',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Damar Hamlin',
#   'player_id': 4036060,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'TD',
#   'team': 'Pittsburgh'},
#  {'category': 'puntReturns',
#   'conference': 'ACC',
#   'player': 'Jordan Addison',
#   'player_id': 4429205,
#   'season': None,
#   'stat': 21.0,
#   'stat_type': 'LONG',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Buddy Mack III',
#   'player_id': 4689567,
#   'season': None,
#   'stat': 0.0,
#   'stat_type': 'TD',
#   'team': 'Pittsburgh'},
#  {'category': 'defensive',
#   'conference': 'ACC',
#   'player': 'Paris Ford',
#   'player_id': 4240705,
#   'season': None,
#   'stat': 41.0,
#   'stat_type': 'TOT',
#   'team': 'Pittsburgh'}]
